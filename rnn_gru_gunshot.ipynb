# %% [markdown]
# <a href="https://colab.research.google.com/github/sayandeepmaity/vseven_lumi/blob/main/rnn_gru_gunshot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import confusion_matrix, classification_report, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping


gunshot_data = pd.read_csv('/content/drive/MyDrive/sevenlumi_data/data_to_fed/cleaned_features.csv')
non_gunshot_data = pd.read_csv('/content/drive/MyDrive/sevenlumi_data/data_to_fed/cleaned_non_gunshot_features.csv')


drop_columns = ['Gun_Type', 'Distance', 'X', 'Y', 'Z', 'Mic', 'Arrival_Time_Difference']
gunshot_data = gunshot_data.drop(columns=drop_columns)
non_gunshot_data = non_gunshot_data.drop(columns=drop_columns)


data = pd.concat([gunshot_data, non_gunshot_data], ignore_index=True)


X = data.drop(columns=['Gunshot'])
y = data['Gunshot']


scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)


X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42, stratify=y)


X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))


class_weights = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)
class_weight_dict = dict(zip(np.unique(y_train), class_weights))
print("Class Weights:", class_weight_dict)


model = Sequential()
model.add(GRU(units=128, return_sequences=True, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
model.add(Dropout(0.3))
model.add(GRU(units=64, return_sequences=False))
model.add(Dropout(0.3))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=1, activation='sigmoid'))


model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])


early_stop = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)


history = model.fit(
    X_train_reshaped, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_test_reshaped, y_test),
    callbacks=[early_stop],
    class_weight=class_weight_dict,
    verbose=1
)

test_loss, test_accuracy = model.evaluate(X_test_reshaped, y_test)
print(f"Test Loss: {test_loss}")
print(f"Test Accuracy: {test_accuracy}")


plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()


y_pred_prob = model.predict(X_test_reshaped)
y_pred = (y_pred_prob > 0.5).astype(int)


cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=[0, 1])
disp.plot(cmap='Blues')
plt.title('Confusion Matrix')
plt.show()


print("Classification Report:\n")
print(classification_report(y_test, y_pred, target_names=['Non-Gunshot', 'Gunshot']))
# Out:
# Class Weights: {np.int64(0): np.float64(5.15035799522673), np.int64(1): np.float64(0.5537593020272004)}
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 8s 13ms/step - accuracy: 0.8255 - loss: 0.4445 - val_accuracy: 0.9769 - val_loss: 0.1130
# Epoch 2/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9822 - loss: 0.0841 - val_accuracy: 0.9694 - val_loss: 0.0966
# Epoch 3/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9887 - loss: 0.0407 - val_accuracy: 0.9954 - val_loss: 0.0404
# Epoch 4/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9952 - loss: 0.0255 - val_accuracy: 0.9963 - val_loss: 0.0318
# Epoch 5/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9944 - loss: 0.0424 - val_accuracy: 0.9954 - val_loss: 0.0252
# Epoch 6/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9959 - loss: 0.0292 - val_accuracy: 0.9935 - val_loss: 0.0256
# Epoch 7/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9938 - loss: 0.0300 - val_accuracy: 0.9981 - val_loss: 0.0117
# Epoch 8/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9936 - loss: 0.0275 - val_accuracy: 0.9963 - val_loss: 0.0120
# Epoch 9/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9955 - loss: 0.0303 - val_accuracy: 0.9981 - val_loss: 0.0077
# Epoch 10/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9962 - loss: 0.0164 - val_accuracy: 0.9981 - val_loss: 0.0078
# Epoch 11/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9976 - loss: 0.0125 - val_accuracy: 0.9981 - val_loss: 0.0064
# Epoch 12/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 11ms/step - accuracy: 0.9977 - loss: 0.0124 - val_accuracy: 0.9981 - val_loss: 0.0052
# Epoch 13/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9967 - loss: 0.0090 - val_accuracy: 0.9981 - val_loss: 0.0038
# Epoch 14/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9985 - loss: 0.0096 - val_accuracy: 0.9898 - val_loss: 0.0273
# Epoch 15/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9941 - loss: 0.0144 - val_accuracy: 0.9981 - val_loss: 0.0032
# Epoch 16/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0073 - val_accuracy: 0.9981 - val_loss: 0.0065
# Epoch 17/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9989 - loss: 0.0066 - val_accuracy: 0.9981 - val_loss: 0.0029
# Epoch 18/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9959 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 19/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9981 - loss: 0.0060 - val_accuracy: 1.0000 - val_loss: 0.0014
# Epoch 20/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9967 - loss: 0.0102 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 21/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9975 - loss: 0.0061 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 22/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 7.3958e-04
# Epoch 23/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9937 - loss: 0.0134 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 24/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 7.0029e-04
# Epoch 25/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 26/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9974 - loss: 0.0029 - val_accuracy: 0.9944 - val_loss: 0.0107
# Epoch 27/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9946 - loss: 0.0202 - val_accuracy: 0.9991 - val_loss: 0.0040
# Epoch 28/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 1.0000 - val_loss: 4.2675e-04
# Epoch 29/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 3.3276e-04
# Epoch 30/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.1954e-04 - val_accuracy: 1.0000 - val_loss: 2.9401e-04
# Epoch 31/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9996 - loss: 0.0017 - val_accuracy: 1.0000 - val_loss: 3.0298e-04
# Epoch 32/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9991 - loss: 0.0034 - val_accuracy: 0.9981 - val_loss: 0.0153
# Epoch 33/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 3.2419e-04
# Epoch 34/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 1.0000 - val_loss: 3.2125e-04
# Epoch 35/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9997 - loss: 7.6154e-04 - val_accuracy: 1.0000 - val_loss: 2.3452e-04
# Epoch 36/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9990 - loss: 0.0012 - val_accuracy: 1.0000 - val_loss: 1.1869e-04
# Epoch 37/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 1.3538e-04
# Epoch 38/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9988 - loss: 0.0033 - val_accuracy: 1.0000 - val_loss: 1.3235e-04
# Epoch 39/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9947 - loss: 0.0082 - val_accuracy: 1.0000 - val_loss: 4.5869e-04
# Epoch 40/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 7.8595e-04 - val_accuracy: 1.0000 - val_loss: 8.7219e-05
# Epoch 41/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9999 - loss: 5.8439e-04 - val_accuracy: 1.0000 - val_loss: 6.3992e-05
# Epoch 42/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9987 - loss: 0.0086 - val_accuracy: 1.0000 - val_loss: 5.9818e-05
# Epoch 43/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9992 - loss: 0.0025 - val_accuracy: 1.0000 - val_loss: 6.8080e-04
# Epoch 44/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - accuracy: 1.0000 - loss: 4.1679e-04 - val_accuracy: 1.0000 - val_loss: 6.5211e-05
# Epoch 45/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 1.0000 - loss: 4.3263e-04 - val_accuracy: 1.0000 - val_loss: 3.6756e-05
# Epoch 46/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9999 - loss: 1.5748e-04 - val_accuracy: 1.0000 - val_loss: 4.0823e-05
# Epoch 47/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9987 - loss: 0.0035 - val_accuracy: 0.9880 - val_loss: 0.0676
# Epoch 48/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9932 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 1.0815e-04
# Epoch 49/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9998 - loss: 9.2408e-04 - val_accuracy: 1.0000 - val_loss: 1.3704e-04
# Epoch 50/50
# 135/135 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9999 - loss: 4.8462e-04 - val_accuracy: 1.0000 - val_loss: 1.4193e-04
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 1.0000 - loss: 1.7383e-05
# Test Loss: 3.6756027839146554e-05
# Test Accuracy: 1.0
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  Non-Gunshot       1.00      1.00      1.00       105
#      Gunshot       1.00      1.00      1.00       975
#
#     accuracy                           1.00      1080
#    macro avg       1.00      1.00      1.00      1080
# weighted avg       1.00      1.00      1.00      1080

# %%
model.save('/content/drive/MyDrive/sevenlumi_data/models/rnn_gru_gunshot_detector_model.h5')

print("Model saved successfully!")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved successfully!
